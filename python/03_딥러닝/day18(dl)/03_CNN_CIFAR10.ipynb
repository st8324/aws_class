# %%
# CIFAR : 캐나다 고등 연구소 약자
# 10 : 분류 10개
# - 비행기, 자동차, 새, 고양이, 사슴, 개, 개구리, 말, 배, 트럭
# 이미지 총 6만장. 학습 5만, 테스트 1만
# 크기 32 x 32

# %%
# 데이터 생성, 독립/종속 분리, 훈련/테스트 분리
import tensorflow as tf
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.cifar10.load_data()

# %%
# 10가지 분류명(확인용)
class_names = [
	'airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck'
]

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
# 콜백
callbacks = [
	EarlyStopping(monitor='val_loss', patience=5,restore_best_weights=True),
	ModelCheckpoint(filepath='best_cifar10_model.keras', monitor='val_accuracy', save_best_only=True, verbose=1),
	ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6)
]

# %%
# 파이프라인
from tensorflow.data import Dataset

DATASET_SIZE = 50000
TRAIN_SIZE = int(DATASET_SIZE * 0.8)
VAL_SIZE = int(DATASET_SIZE * 0.2)

dataset = Dataset.from_tensor_slices((X_train, y_train))
# 섞음 
dataset = dataset.shuffle(buffer_size=DATASET_SIZE)
# 훈련 데이터셋
train_dataset = dataset.take(TRAIN_SIZE)
# 검증 데이터셋
val_dataset = dataset.skip(TRAIN_SIZE)

train_dataset = train_dataset.batch(128).prefetch(tf.data.AUTOTUNE)
val_dataset = val_dataset.batch(128).prefetch(tf.data.AUTOTUNE)

# %%
# 데이터 증강 : 이미지를 돌리거나, 색상 반전등과 같이 변형을 한 복사본을 만들어 학습
data_augmentation = tf.keras.Sequential([
	tf.keras.layers.RandomFlip("horizontal"), # 좌우 반전
	tf.keras.layers.RandomRotation(0.2) # 20% 범위 내에서 무작위 회전
])

# %%
# 모델 설계
model = tf.keras.models.Sequential([
	tf.keras.Input((32, 32, 3)),
	# 데이터 증강 
	# data_augmentation, 
	# 정규화
	tf.keras.layers.Rescaling(1./255),

	tf.keras.layers.Conv2D(32, (3,3), padding='same', activation='relu'),
	tf.keras.layers.BatchNormalization(),
	tf.keras.layers.Conv2D(32, (3,3), padding='same', activation='relu'),
	tf.keras.layers.MaxPooling2D(2,2),
	tf.keras.layers.Dropout(0.25),
	# 이 때 이미지 크기 16 x 16

	# 블록 2
	tf.keras.layers.Conv2D(64, (3,3), padding='same', activation='relu'),
	tf.keras.layers.BatchNormalization(),
	tf.keras.layers.Conv2D(64, (3,3), padding='same', activation='relu'),
	tf.keras.layers.MaxPooling2D(2,2),
	tf.keras.layers.Dropout(0.25),
	# 이 때 이미지 크기 8 x 8

	# 블록 3
	tf.keras.layers.Conv2D(128, (3,3), padding='same', activation='relu'),
	tf.keras.layers.BatchNormalization(),
	tf.keras.layers.GlobalAveragePooling2D(),

	# 분류기
	tf.keras.layers.Dense(10, activation='softmax')
])

# %%
# 모델 설정
model.compile(
	optimizer='adam', 
	loss='sparse_categorical_crossentropy', 
	metrics=['accuracy']
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
# 학습
history = model.fit(
	train_dataset,
	epochs = 50,
	verbose = 1,
	validation_data=val_dataset,
	callbacks = callbacks,
	batch_size=128,
)
# Out:
# Epoch 1/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - accuracy: 0.6314 - loss: 1.0306
# Epoch 1: val_accuracy improved from 0.12380 to 0.64900, saving model to best_cifar10_model.keras
#
# Epoch 1: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 73s 232ms/step - accuracy: 0.6430 - loss: 1.0060 - val_accuracy: 0.6490 - val_loss: 1.0069 - learning_rate: 0.0010
# Epoch 2/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.6823 - loss: 0.9054
# Epoch 2: val_accuracy improved from 0.64900 to 0.65040, saving model to best_cifar10_model.keras
#
# Epoch 2: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 73s 232ms/step - accuracy: 0.6871 - loss: 0.8908 - val_accuracy: 0.6504 - val_loss: 1.0050 - learning_rate: 0.0010
# Epoch 3/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 0.7121 - loss: 0.8245
# Epoch 3: val_accuracy improved from 0.65040 to 0.67450, saving model to best_cifar10_model.keras
#
# Epoch 3: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 74s 235ms/step - accuracy: 0.7144 - loss: 0.8135 - val_accuracy: 0.6745 - val_loss: 0.9244 - learning_rate: 0.0010
# Epoch 4/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.7329 - loss: 0.7619
# Epoch 4: val_accuracy improved from 0.67450 to 0.74090, saving model to best_cifar10_model.keras
#
# Epoch 4: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 71s 225ms/step - accuracy: 0.7377 - loss: 0.7498 - val_accuracy: 0.7409 - val_loss: 0.7385 - learning_rate: 0.0010
# Epoch 5/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.7541 - loss: 0.6978
# Epoch 5: val_accuracy did not improve from 0.74090
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 72s 229ms/step - accuracy: 0.7587 - loss: 0.6860 - val_accuracy: 0.7272 - val_loss: 0.7637 - learning_rate: 0.0010
# Epoch 6/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.7722 - loss: 0.6499
# Epoch 6: val_accuracy improved from 0.74090 to 0.77940, saving model to best_cifar10_model.keras
#
# Epoch 6: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 72s 229ms/step - accuracy: 0.7733 - loss: 0.6484 - val_accuracy: 0.7794 - val_loss: 0.6347 - learning_rate: 0.0010
# Epoch 7/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.7909 - loss: 0.6014
# Epoch 7: val_accuracy improved from 0.77940 to 0.81470, saving model to best_cifar10_model.keras
#
# Epoch 7: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 73s 233ms/step - accuracy: 0.7871 - loss: 0.6102 - val_accuracy: 0.8147 - val_loss: 0.5294 - learning_rate: 0.0010
# Epoch 8/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.8006 - loss: 0.5668
# Epoch 8: val_accuracy improved from 0.81470 to 0.82250, saving model to best_cifar10_model.keras
#
# Epoch 8: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 72s 230ms/step - accuracy: 0.7993 - loss: 0.5763 - val_accuracy: 0.8225 - val_loss: 0.5143 - learning_rate: 0.0010
# Epoch 9/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.8094 - loss: 0.5523
# Epoch 9: val_accuracy did not improve from 0.82250
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 71s 225ms/step - accuracy: 0.8079 - loss: 0.5530 - val_accuracy: 0.7913 - val_loss: 0.6123 - learning_rate: 0.0010
# Epoch 10/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 0.8148 - loss: 0.5358
# Epoch 10: val_accuracy did not improve from 0.82250
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 75s 238ms/step - accuracy: 0.8128 - loss: 0.5358 - val_accuracy: 0.7749 - val_loss: 0.6824 - learning_rate: 0.0010
# Epoch 11/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - accuracy: 0.8235 - loss: 0.5114
# Epoch 11: val_accuracy improved from 0.82250 to 0.84380, saving model to best_cifar10_model.keras
#
# Epoch 11: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 74s 237ms/step - accuracy: 0.8229 - loss: 0.5142 - val_accuracy: 0.8438 - val_loss: 0.4520 - learning_rate: 0.0010
# Epoch 12/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.8346 - loss: 0.4778
# Epoch 12: val_accuracy improved from 0.84380 to 0.84780, saving model to best_cifar10_model.keras
#
# Epoch 12: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 71s 226ms/step - accuracy: 0.8295 - loss: 0.4905 - val_accuracy: 0.8478 - val_loss: 0.4563 - learning_rate: 0.0010
# Epoch 13/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.8355 - loss: 0.4739
# Epoch 13: val_accuracy did not improve from 0.84780
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 75s 239ms/step - accuracy: 0.8342 - loss: 0.4760 - val_accuracy: 0.8228 - val_loss: 0.5141 - learning_rate: 0.0010
# Epoch 14/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.8400 - loss: 0.4547
# Epoch 14: val_accuracy improved from 0.84780 to 0.85970, saving model to best_cifar10_model.keras
#
# Epoch 14: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 73s 232ms/step - accuracy: 0.8407 - loss: 0.4577 - val_accuracy: 0.8597 - val_loss: 0.3977 - learning_rate: 0.0010
# Epoch 15/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.8411 - loss: 0.4484
# Epoch 15: val_accuracy improved from 0.85970 to 0.86090, saving model to best_cifar10_model.keras
#
# Epoch 15: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 70s 222ms/step - accuracy: 0.8419 - loss: 0.4521 - val_accuracy: 0.8609 - val_loss: 0.4021 - learning_rate: 0.0010
# Epoch 16/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.8521 - loss: 0.4252
# Epoch 16: val_accuracy did not improve from 0.86090
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 70s 222ms/step - accuracy: 0.8486 - loss: 0.4354 - val_accuracy: 0.8551 - val_loss: 0.4186 - learning_rate: 0.0010
# Epoch 17/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.8527 - loss: 0.4242
# Epoch 17: val_accuracy improved from 0.86090 to 0.86290, saving model to best_cifar10_model.keras
#
# Epoch 17: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 71s 227ms/step - accuracy: 0.8505 - loss: 0.4254 - val_accuracy: 0.8629 - val_loss: 0.3942 - learning_rate: 0.0010
# Epoch 18/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.8562 - loss: 0.4150
# Epoch 18: val_accuracy improved from 0.86290 to 0.87140, saving model to best_cifar10_model.keras
#
# Epoch 18: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 71s 228ms/step - accuracy: 0.8561 - loss: 0.4147 - val_accuracy: 0.8714 - val_loss: 0.3696 - learning_rate: 0.0010
# Epoch 19/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.8605 - loss: 0.3999
# Epoch 19: val_accuracy improved from 0.87140 to 0.89150, saving model to best_cifar10_model.keras
#
# Epoch 19: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 73s 234ms/step - accuracy: 0.8593 - loss: 0.4010 - val_accuracy: 0.8915 - val_loss: 0.3200 - learning_rate: 0.0010
# Epoch 20/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.8660 - loss: 0.3843
# Epoch 20: val_accuracy improved from 0.89150 to 0.89620, saving model to best_cifar10_model.keras
#
# Epoch 20: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 70s 224ms/step - accuracy: 0.8624 - loss: 0.3944 - val_accuracy: 0.8962 - val_loss: 0.2967 - learning_rate: 0.0010
# Epoch 21/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 0.8644 - loss: 0.3819
# Epoch 21: val_accuracy did not improve from 0.89620
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 74s 236ms/step - accuracy: 0.8648 - loss: 0.3832 - val_accuracy: 0.8600 - val_loss: 0.3965 - learning_rate: 0.0010
# Epoch 22/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 0.8689 - loss: 0.3758
# Epoch 22: val_accuracy improved from 0.89620 to 0.89740, saving model to best_cifar10_model.keras
#
# Epoch 22: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 77s 246ms/step - accuracy: 0.8694 - loss: 0.3775 - val_accuracy: 0.8974 - val_loss: 0.2927 - learning_rate: 0.0010
# Epoch 23/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.8727 - loss: 0.3645
# Epoch 23: val_accuracy did not improve from 0.89740
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 71s 227ms/step - accuracy: 0.8684 - loss: 0.3744 - val_accuracy: 0.8894 - val_loss: 0.3179 - learning_rate: 0.0010
# Epoch 24/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.8753 - loss: 0.3544
# Epoch 24: val_accuracy did not improve from 0.89740
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 75s 238ms/step - accuracy: 0.8720 - loss: 0.3615 - val_accuracy: 0.8792 - val_loss: 0.3399 - learning_rate: 0.0010
# Epoch 25/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.8797 - loss: 0.3483
# Epoch 25: val_accuracy improved from 0.89740 to 0.90620, saving model to best_cifar10_model.keras
#
# Epoch 25: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 71s 226ms/step - accuracy: 0.8753 - loss: 0.3541 - val_accuracy: 0.9062 - val_loss: 0.2730 - learning_rate: 0.0010
# Epoch 26/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.8824 - loss: 0.3394
# Epoch 26: val_accuracy did not improve from 0.90620
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 70s 222ms/step - accuracy: 0.8798 - loss: 0.3447 - val_accuracy: 0.8722 - val_loss: 0.3639 - learning_rate: 0.0010
# Epoch 27/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - accuracy: 0.8814 - loss: 0.3316
# Epoch 27: val_accuracy did not improve from 0.90620
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 77s 245ms/step - accuracy: 0.8788 - loss: 0.3407 - val_accuracy: 0.8984 - val_loss: 0.2970 - learning_rate: 0.0010
# Epoch 28/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.8858 - loss: 0.3289
# Epoch 28: val_accuracy improved from 0.90620 to 0.90960, saving model to best_cifar10_model.keras
#
# Epoch 28: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 77s 244ms/step - accuracy: 0.8820 - loss: 0.3383 - val_accuracy: 0.9096 - val_loss: 0.2638 - learning_rate: 0.0010
# Epoch 29/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.8842 - loss: 0.3253
# Epoch 29: val_accuracy improved from 0.90960 to 0.91750, saving model to best_cifar10_model.keras
#
# Epoch 29: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 71s 228ms/step - accuracy: 0.8811 - loss: 0.3358 - val_accuracy: 0.9175 - val_loss: 0.2397 - learning_rate: 0.0010
# Epoch 30/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.8903 - loss: 0.3103
# Epoch 30: val_accuracy did not improve from 0.91750
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 70s 224ms/step - accuracy: 0.8874 - loss: 0.3194 - val_accuracy: 0.9000 - val_loss: 0.2907 - learning_rate: 0.0010
# Epoch 31/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - accuracy: 0.8903 - loss: 0.3129
# Epoch 31: val_accuracy did not improve from 0.91750
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 73s 232ms/step - accuracy: 0.8856 - loss: 0.3226 - val_accuracy: 0.9136 - val_loss: 0.2497 - learning_rate: 0.0010
# Epoch 32/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.8911 - loss: 0.3029
# Epoch 32: val_accuracy improved from 0.91750 to 0.92140, saving model to best_cifar10_model.keras
#
# Epoch 32: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 72s 231ms/step - accuracy: 0.8889 - loss: 0.3142 - val_accuracy: 0.9214 - val_loss: 0.2305 - learning_rate: 0.0010
# Epoch 33/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.8918 - loss: 0.3055
# Epoch 33: val_accuracy did not improve from 0.92140
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 73s 234ms/step - accuracy: 0.8906 - loss: 0.3106 - val_accuracy: 0.9137 - val_loss: 0.2410 - learning_rate: 0.0010
# Epoch 34/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - accuracy: 0.8970 - loss: 0.2955
# Epoch 34: val_accuracy did not improve from 0.92140
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 76s 243ms/step - accuracy: 0.8916 - loss: 0.3057 - val_accuracy: 0.9022 - val_loss: 0.2731 - learning_rate: 0.0010
# Epoch 35/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.8952 - loss: 0.2947
# Epoch 35: val_accuracy did not improve from 0.92140
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 72s 231ms/step - accuracy: 0.8934 - loss: 0.3018 - val_accuracy: 0.9001 - val_loss: 0.2777 - learning_rate: 0.0010
# Epoch 36/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.9047 - loss: 0.2675
# Epoch 36: val_accuracy improved from 0.92140 to 0.94850, saving model to best_cifar10_model.keras
#
# Epoch 36: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 73s 234ms/step - accuracy: 0.9058 - loss: 0.2686 - val_accuracy: 0.9485 - val_loss: 0.1581 - learning_rate: 5.0000e-04
# Epoch 37/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.9171 - loss: 0.2455
# Epoch 37: val_accuracy improved from 0.94850 to 0.95680, saving model to best_cifar10_model.keras
#
# Epoch 37: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 75s 238ms/step - accuracy: 0.9129 - loss: 0.2510 - val_accuracy: 0.9568 - val_loss: 0.1454 - learning_rate: 5.0000e-04
# Epoch 38/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.9137 - loss: 0.2508
# Epoch 38: val_accuracy did not improve from 0.95680
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 72s 231ms/step - accuracy: 0.9119 - loss: 0.2529 - val_accuracy: 0.9552 - val_loss: 0.1453 - learning_rate: 5.0000e-04
# Epoch 39/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9165 - loss: 0.2371
# Epoch 39: val_accuracy did not improve from 0.95680
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 67s 215ms/step - accuracy: 0.9131 - loss: 0.2470 - val_accuracy: 0.9543 - val_loss: 0.1401 - learning_rate: 5.0000e-04
# Epoch 40/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9148 - loss: 0.2444
# Epoch 40: val_accuracy did not improve from 0.95680
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 64s 203ms/step - accuracy: 0.9147 - loss: 0.2445 - val_accuracy: 0.9546 - val_loss: 0.1420 - learning_rate: 5.0000e-04
# Epoch 41/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9187 - loss: 0.2313
# Epoch 41: val_accuracy did not improve from 0.95680
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 67s 214ms/step - accuracy: 0.9158 - loss: 0.2364 - val_accuracy: 0.9421 - val_loss: 0.1730 - learning_rate: 5.0000e-04
# Epoch 42/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.9167 - loss: 0.2356
# Epoch 42: val_accuracy did not improve from 0.95680
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 65s 209ms/step - accuracy: 0.9165 - loss: 0.2367 - val_accuracy: 0.9532 - val_loss: 0.1479 - learning_rate: 5.0000e-04
# Epoch 43/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.9233 - loss: 0.2227
# Epoch 43: val_accuracy improved from 0.95680 to 0.96740, saving model to best_cifar10_model.keras
#
# Epoch 43: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 63s 202ms/step - accuracy: 0.9240 - loss: 0.2219 - val_accuracy: 0.9674 - val_loss: 0.1169 - learning_rate: 2.5000e-04
# Epoch 44/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.9279 - loss: 0.2054
# Epoch 44: val_accuracy did not improve from 0.96740
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 64s 206ms/step - accuracy: 0.9257 - loss: 0.2121 - val_accuracy: 0.9641 - val_loss: 0.1146 - learning_rate: 2.5000e-04
# Epoch 45/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.9277 - loss: 0.2118
# Epoch 45: val_accuracy did not improve from 0.96740
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 64s 205ms/step - accuracy: 0.9276 - loss: 0.2120 - val_accuracy: 0.9665 - val_loss: 0.1162 - learning_rate: 2.5000e-04
# Epoch 46/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.9281 - loss: 0.2051
# Epoch 46: val_accuracy improved from 0.96740 to 0.97650, saving model to best_cifar10_model.keras
#
# Epoch 46: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 67s 213ms/step - accuracy: 0.9279 - loss: 0.2087 - val_accuracy: 0.9765 - val_loss: 0.0956 - learning_rate: 2.5000e-04
# Epoch 47/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.9288 - loss: 0.2039
# Epoch 47: val_accuracy did not improve from 0.97650
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 64s 205ms/step - accuracy: 0.9271 - loss: 0.2069 - val_accuracy: 0.9724 - val_loss: 0.1027 - learning_rate: 2.5000e-04
# Epoch 48/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.9272 - loss: 0.2075
# Epoch 48: val_accuracy did not improve from 0.97650
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 66s 212ms/step - accuracy: 0.9257 - loss: 0.2113 - val_accuracy: 0.9727 - val_loss: 0.1030 - learning_rate: 2.5000e-04
# Epoch 49/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.9274 - loss: 0.2042
# Epoch 49: val_accuracy did not improve from 0.97650
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 73s 233ms/step - accuracy: 0.9259 - loss: 0.2076 - val_accuracy: 0.9646 - val_loss: 0.1141 - learning_rate: 2.5000e-04
# Epoch 50/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9306 - loss: 0.1997
# Epoch 50: val_accuracy did not improve from 0.97650
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 69s 221ms/step - accuracy: 0.9307 - loss: 0.1974 - val_accuracy: 0.9735 - val_loss: 0.0955 - learning_rate: 1.2500e-04

# %%
# 평가
_, acc = model.evaluate(X_test, y_test)
print(f'정확도 : {acc}')
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8583 - loss: 0.4448
# 정확도 : 0.858299970626831

# %%
# 성능 시각화
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'], label='Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model accuracy')
plt.xlabel('Epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
# 이미지 시각화
predictions = model.predict(X_test[:16])
fig, axes = plt.subplots(4, 4, figsize=(8,8))
for i, ax in enumerate(axes.flat):
	
	ax.imshow(X_test[i])
	predict = predictions[i].argmax()
	true = y_test[i][0]
	ax.set_title(f"{class_names[predict]},{class_names[true]}")
	ax.axis('off')

plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step

# %%
import cv2
import numpy as np
# 예측
def model_predict_idx(model, img_path):

	img = cv2.imread(img_path, cv2.IMREAD_COLOR)

	resize_img = cv2.resize(img, (32, 32))

	predict = model.predict(np.array([resize_img]))

	result = np.argmax(predict)
	return class_names[result]

# %%
# 예측
result = model_predict_idx(model, '../data/img/cifar10_0_1.png')
print(f'airplain? {result}')
result = model_predict_idx(model, '../data/img/cifar10_9_1.png')
print(f'truck? {result}')
result = model_predict_idx(model, '../data/img/cifar10_9_2.png')
print(f'truck? {result}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# airplain? airplane
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# truck? automobile
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# truck? automobile

# %%
# 학습한 모델 저장
model.save('cnn_cifar.keras')

# %%
# 모델 불러오기
model2 = tf.keras.models.load_model('best_cifar10_model.keras')
result = model_predict_idx(model2, '../data/img/cifar10_9_2.png')
print(f'truck? {result}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# truck? automobile
